# %% [markdown]
# # Evaluation Results Visualization
#
# This notebook loads and visualizes evaluation results from CSV files with embedded images.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import base64
from io import BytesIO
from PIL import Image
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# ## Load CSV File

# %%
# import pandas as pd

# df = pd.read_csv("/Users/paulabartabajo/src/liquid/ImageClassifier/image-to-json/evals/predictions_20250924_151458.csv")
# df.head(10)

# %%
from image_to_json.report import EvalReport

eval_report = EvalReport.from_last_csv()

eval_report.print()

# %% [markdown]
# ## Calculate Accuracy

# %%
eval_report.get_accuracy()
# Out:
# 0.7

# %% [markdown]
# ## View Specific Image by Index

# %%
idx = 0
row = df.iloc[idx]

img = decode_image(row['image_base64'])
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.axis('off')
plt.title(
    f"Ground Truth: {row['ground_truth']}\nPredicted: {row['predicted']}\nCorrect: {row['correct']}",
    fontsize=14
)
plt.show()
